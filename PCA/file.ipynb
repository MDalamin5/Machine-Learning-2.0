# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DATA/train.csv')
df.sample(6)
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 17027      3       0       0       0       0       0       0       0       0
# 29738      5       0       0       0       0       0       0       0       0
# 7126       1       0       0       0       0       0       0       0       0
# 33309      8       0       0       0       0       0       0       0       0
# 4908       0       0       0       0       0       0       0       0       0
# 27887      6       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 17027       0  ...         0         0         0         0         0
# 29738       0  ...         0         0         0         0         0
# 7126        0  ...         0         0         0         0         0
# 33309       0  ...         0         0         0         0         0
# 4908        0  ...         0         0         0         0         0
# 27887       0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 17027         0         0         0         0         0
# 29738         0         0         0         0         0
# 7126          0         0         0         0         0
# 33309         0         0         0         0         0
# 4908          0         0         0         0         0
# 27887         0         0         0         0         0
#
# [6 rows x 785 columns]

# %%
plt.imshow(df.iloc[27887,1:].values.reshape(28,28))
